# %%
import os
import json
import torch
from PIL import Image
import matplotlib.pyplot as plt
from torch.utils.data import Dataset
import torchvision
from torchvision.transforms import transforms

# %%
save_dir = r"C:\Users\dra04\OneDrive - 경희대학교\바탕 화면\test\json"

json_files = []
for file in os.listdir(save_dir):
    json_files.append(os.path.join(save_dir, file))

print("데이터 개수:", len(json_files))
# Out:
# 데이터 개수: 35

# %%
image_dir = r"C:\Users\dra04\OneDrive - 경희대학교\바탕 화면\test\picture"

image_files = []
for file in os.listdir(image_dir):
    image_files.append(os.path.join(image_dir, file))

print("이미지 개수:", len(image_files))
# Out:
# 이미지 개수: 35

# %%
clothes_class = ["아우터", "하의", "원피스", "상의"]
clothes_xy = {"outer_xy":None, "pants_xy":None, "onepiece_xy":None, "shirt_xy":None}
clothes_fabric = {"outer_fabric":None, "pants_fabric":None, "onepiece_fabric":None, "shirt_fabric":None}

image_dict = {}

for file in json_files:
    with open(file, "rb") as f:
        data = json.load(f)
        file_name = data['이미지 정보']['이미지 파일명']
        for cls, xy, fabric in zip(clothes_class, clothes_xy, clothes_fabric):
            clothes_xy[xy] = data['데이터셋 정보']['데이터셋 상세설명']['렉트좌표'][cls][0].values()
            if not clothes_xy[xy]:
                continue
            try:
                clothes_fabric[fabric] = data['데이터셋 정보']['데이터셋 상세설명']['라벨링'][cls][0]['소재']
            except:
                print(file_name)
                print("--------------------")
        # print(clothes_xy)
        # print(clothes_fabric)

    for xy, fabric in zip(clothes_xy.values(), clothes_fabric.values()):
        if not xy:
            continue
        image_dict[(file_name, xy)] = fabric

image_dict
# Out:
# 1 (30120).jpg
# --------------------
# @기획샘플@-ops4537k04(2)-바이보늬(샘플,주름멜빵)-얼굴컷,어두운거는 밝게 보정해주시고 치마가 예쁘게 나온걸로 사진 많이 넣어주세여~-IMG_E0624.JPG
# --------------------
# {('(121)IMG_1.jpg', dict_values([74.5, 538.098, 485, 324])): ['우븐'],
#  ('(131)IMG_1.jpg', dict_values([192.5, 448.731, 303, 323])): ['니트'],
#  ('(131)IMG_1.jpg', dict_values([231.5, 467.724, 225, 450])): ['우븐'],
#  ('(141)IMG_1.jpg', dict_values([192.5, 470.5, 328, 319])): ['니트'],
#  ('(141)IMG_1.jpg', dict_values([241.5, 520.5, 285, 537])): ['우븐'],
#  ('(151)IMG_1.jpg', dict_values([202.5, 68.5, 416, 476])): ['트위드'],
#  ('(151)IMG_1.jpg', dict_values([265.5, 73.5, 252, 525])): ['우븐'],
#  ('(19)IMG_1.jpg', dict_values([291.5, 530.701, 163, 298])): ['벨벳'],
#  ('(19)IMG_1.jpg', dict_values([298.5, 411.345, 161, 158])): ['저지'],
#  ('(191)IMG_1.jpg', dict_values([256.5, 575.5, 298, 403])): ['우븐'],
#  ('(201)IMG_1.jpg', dict_values([332.5, 674.5, 127, 300])): ['우븐'],
#  ('(201)IMG_1.jpg', dict_values([307.5, 518.5, 160, 213])): ['우븐'],
#  ('(211)IMG_1.jpg', dict_values([205.5, 420.5, 343, 399])): ['시폰'],
#  ('(356)IMG_1.jpg', dict_values([263.5, 613.5, 143, 361])): ['데님'],
#  ('(356)IMG_1.jpg', dict_values([248.5, 436.5, 197, 268])): ['우븐'],
#  ('(387)IMG_1.jpg', dict_values([219.5, 439.5, 153, 306])): ['우븐'],
#  ('(55)IMG_1.jpg', dict_values([289.5, 431.338, 169, 397])): ['우븐'],
#  ('(89)IMG_1.jpg', dict_values([241.5, 557.291, 210, 263])): ['니트'],
#  ('(89)IMG_1.jpg', dict_values([258.5, 548.094, 182, 410])): ['우븐'],
#  ('(9)IMG_1.jpg', dict_values([256.5, 469.724, 261, 305])): ['울/캐시미어'],
#  ('(9)IMG_1.jpg', dict_values([310.5, 589.678, 145, 265])): ['벨벳'],
#  ('(99)IMG_1.jpg', dict_values([298.5, 500.712, 177, 382])): ['우븐'],
#  ('1 (15046).jpg', dict_values([231.5, 540.297, 254, 398])): ['시폰'],
#  ('1 (15056).jpg', dict_values([214.5, 499.712, 292, 441])): ['시폰'],
#  ('1 (15066).jpg', dict_values([294.5, 246.9, 235, 431])): ['시폰'],
#  ('1 (25825).JPG', dict_values([365.5, 416.5, 175, 332])): ['우븐'],
#  ('1 (25825).JPG', dict_values([377.5, 217.5, 200, 259])): ['우븐'],
#  ('1 (30120).jpg', dict_values([210.0, 476.5, 175, 237])): ['우븐'],
#  ('1 (30120).jpg', dict_values([209.0, 476.5, 175, 383])): ['시폰'],
#  ('1 (30132).jpg', dict_values([265.5, 469.324, 198, 238])): ['우븐'],
#  ('1 (30355).jpg', dict_values([368.5, 413.7, 157, 361])): ['우븐'],
#  ('1 (30355).jpg', dict_values([344.5, 264.7, 198, 258])): ['우븐'],
#  ('1 (30365).jpg', dict_values([391.5, 379.7, 138, 355])): ['우븐'],
#  ('1 (30365).jpg', dict_values([379.5, 258.7, 160, 164])): ['저지'],
#  ('1 (30448).jpg', dict_values([346.5, 358.9, 157, 390])): ['우븐'],
#  ('1 (30448).jpg', dict_values([330.5, 245.9, 172, 244])): ['니트'],
#  ('1 (30458).jpg', dict_values([305.5, 348.3, 169, 422])): ['우븐'],
#  ('1 (30458).jpg', dict_values([319.5, 211.3, 189, 251])): ['니트'],
#  ('1-(9)-004-271-3031-5163-TOP_179_11.jpg',
#   dict_values([222.5, 57.5, 421, 600])): ['우븐'],
#  ('1-(9)-005-272-2,351-7,514-FisrtGI_355_02.jpg',
#   dict_values([317.531, 195.5, 180, 556])): ['우븐', '린넨'],
#  ('1-(9)-005-272-2,351-7,514-FisrtGI_355_02.jpg',
#   dict_values([267.531, 5.5, 266, 226])): ['린넨', '우븐'],
#  ('1-(9)-008-275-2,526-14,877-FLY_324_04.jpg',
#   dict_values([281.0, 356.5, 191, 441])): ['우븐'],
#  ('1-(9)-008-275-2,526-14,877-FLY_324_04.jpg',
#   dict_values([287.0, 2.5, 315, 453])): ['저지'],
#  ('1-(9)-009-276-4,164-19,041-Forme_347_01.jpg',
#   dict_values([239.5, -0.5, 310, 571])): ['우븐'],
#  ('1-(9)-009-276-4,164-19,041-Forme_347_01.jpg',
#   dict_values([332.5, 534.5, 116, 157])): ['데님'],
#  ('1-(9)-009-276-4,164-19,041-Forme_347_11.jpg',
#   dict_values([200.5, -0.5, 254, 591])): ['우븐'],
#  ('1-(9)-009-276-4,164-19,041-Forme_347_11.jpg',
#   dict_values([215.5, 565.5, 174, 126])): ['데님'],
#  ('@기획샘플@-jk2232k04(2)-물고기(샘플,심플숏자켓)-얼굴컷,어두운컷 밝게보정,다리 예쁘게 보정해주세요~-IMG_E0818.JPG',
#   dict_values([270.203, 217.5, 193, 212])): ['우븐'],
#  ('@기획샘플@-jk2232k04(2)-물고기(샘플,심플숏자켓)-얼굴컷,어두운컷 밝게보정,다리 예쁘게 보정해주세요~-IMG_E0818.JPG',
#   dict_values([280.5, 280.5, 178, 372])): ['린넨'],
#  ('@기획샘플@-ops4493k04(3)-물고기(샘플,린넨나시원피스)-얼굴컷,어두운컷 밝게보정,다리 예쁘게 보정해주세요~-IMG_E0821.JPG',
#   dict_values([270.203, 47.5, 317, 390])): ['우븐'],
#  ('@기획샘플@-ops4493k04(3)-물고기(샘플,린넨나시원피스)-얼굴컷,어두운컷 밝게보정,다리 예쁘게 보정해주세요~-IMG_E0821.JPG',
#   dict_values([224.203, 178.5, 291, 549])): ['린넨'],
#  ('@기획샘플@-ops4537k04(2)-바이보늬(샘플,주름멜빵)-얼굴컷,어두운거는 밝게 보정해주시고 치마가 예쁘게 나온걸로 사진 많이 넣어주세여~-IMG_E0624.JPG',
#   dict_values([275.295, 297.507, 199, 388])): ['우븐'],
#  ('@기획샘플@-ops4537k04(2)-바이보늬(샘플,주름멜빵)-얼굴컷,어두운거는 밝게 보정해주시고 치마가 예쁘게 나온걸로 사진 많이 넣어주세여~-IMG_E0624.JPG',
#   dict_values([289.295, 292.507, 154, 88])): ['저지'],
#  ('_98Z5409.jpg', dict_values([134.0, 95.5, 242, 416])): ['저지'],
#  ('_98Z5584.jpg', dict_values([256.0, 638.5, 255, 320])): ['스판덱스'],
#  ('_98Z5584.jpg', dict_values([229.0, 156.5, 348, 565])): ['저지'],
#  ('_MG_0723.jpg', dict_values([235.5, 55.5, 319, 432])): ['시폰']}

# %%
class ClothDataset(Dataset):
    def __init__(self, image_dict, data_dir=r"C:\Users\dra04\OneDrive - 경희대학교\바탕 화면\test\picture"):
        super().__init__()
        self.data_dir = data_dir
        self.image_dict = image_dict
        self.image_files = []

        self.setup()

    def setup(self):
        for (file_name, xy), fabric in self.image_dict.items():
            self.image_files.append((os.path.join(self.data_dir, file_name), xy, fabric))

    def __getitem__(self, idx):
        file_name, xy, fabric = self.image_files[idx]
        x, y, w, h = map(int, xy)
        im = Image.open(file_name)
        im = transforms.ToTensor()(im)
        im = torchvision.transforms.functional.crop(im, y, x, h, w)

        return im, fabric

# %%
dataset = ClothDataset(image_dict)

# %%
plt.imshow(dataset[6][0].permute(1, 2, 0))
